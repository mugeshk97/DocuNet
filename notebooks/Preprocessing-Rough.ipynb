# %%
#  File to preprocess and visualize the data for the model training.
import cv2
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,15)

# %%
img = cv2.imread('/home/mugesh/IB/DocuNet/data/raw_data/gridline/00000010.tif', 0)
# img = cv2.imread('data_new/good/00000002.TIF', 0)
# img = cv2.imread('/home/mugesh/IB/DocuNet/data/raw_data/shaded/00000004.TIF', 0)
# img = cv2.imread('/home/mugesh/IB/DocuNet/data/raw_data/black_border/00001422.tif',0)

# %%
img = cv2.resize(img, (640,640))

# %%
_, img = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(img, cmap='gray')
